# %%
from main import create_random_grid, play_the_game, plot_grid
from IPython import display 
import matplotlib.animation as ani

# %%
grid = create_random_grid(grid_size=25)
turns = play_the_game(start_grid=grid)
turns = [turn for turn in turns]
turns.pop()
animation = plot_grid(turns)
writer = ani.FFMpegWriter(
        fps=1
    )
animation.save('temp.mp4', writer=writer)

# html = display.HTML(video)
# display.display(html)
# Out:
# AAAAAA
# BBBB: counter = 1
# CCCCCC: counter = 1
# DDDDDD
# EEEEEE
# CCCCCC: counter = 2
# DDDDDD
# EEEEEE
# CCCCCC: counter = 3
# DDDDDD
# EEEEEE
# CCCCCC: counter = 4
# DDDDDD
# EEEEEE
# CCCCCC: counter = 5
# DDDDDD
# EEEEEE
# CCCCCC: counter = 6
# DDDDDD
# EEEEEE
# CCCCCC: counter = 7
# DDDDDD
# EEEEEE
# CCCCCC: counter = 8
# DDDDDD
# EEEEEE
# CCCCCC: counter = 9
# DDDDDD
# EEEEEE
# CCCCCC: counter = 10
# DDDDDD
# EEEEEE
# CCCCCC: counter = 11
# DDDDDD
# EEEEEE
# CCCCCC: counter = 12
# DDDDDD
# EEEEEE
# CCCCCC: counter = 13
# DDDDDD
# EEEEEE
# CCCCCC: counter = 14
# DDDDDD
# EEEEEE
# CCCCCC: counter = 15
# DDDDDD
# EEEEEE
# CCCCCC: counter = 16
# DDDDDD
# EEEEEE
# CCCCCC: counter = 17
# DDDDDD
# EEEEEE
# CCCCCC: counter = 18
# DDDDDD
# EEEEEE
# CCCCCC: counter = 19
# DDDDDD
# EEEEEE
# CCCCCC: counter = 20
# DDDDDD
# EEEEEE
# CCCCCC: counter = 21
# DDDDDD
# EEEEEE
# CCCCCC: counter = 22
# DDDDDD
# EEEEEE
# CCCCCC: counter = 23
# DDDDDD
# EEEEEE
# CCCCCC: counter = 24
# DDDDDD
# ...
